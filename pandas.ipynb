# %%
import pandas as pd

df = pd.read_csv('student_data.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
print(df.shape)
print(type(df['StudentID']))
# Out:
# (20, 9)
# <class 'pandas.core.series.Series'>

# %%
#first values
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
#last values
df.tail()
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016  Ziaur Rahman                  94.0             94.0
# 16    PH1017   Afsana Mimi                  90.0             90.0
# 17    PH1018   Babul Ahmed                  88.0             88.0
# 18    PH1019  Faria Rahman                   NaN              NaN
# 19    PH1020    Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %%
#columns
df.columns
# Out:
# Index(['StudentID', 'FullName', 'Data Structure Marks', 'Algorithm Marks',
#        'Python Marks', 'CompletionStatus', 'EnrollmentDate', 'Instructor',
#        'Location'],
#       dtype='object')

# %%
#index
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             20 non-null     object
#  1   FullName              20 non-null     object
#  2   Data Structure Marks  16 non-null     float64
#  3   Algorithm Marks       16 non-null     float64
#  4   Python Marks          15 non-null     float64
#  5   CompletionStatus      20 non-null     object
#  6   EnrollmentDate        20 non-null     object
#  7   Instructor            20 non-null     object
#  8   Location              20 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
#describe
df.describe()
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks
# count             16.000000        16.000000     15.000000
# mean              84.000000        84.000000     85.666667
# std                6.501282         6.501282      5.394000
# min               72.000000        72.000000     76.000000
# 25%               79.500000        79.500000     83.000000
# 50%               85.500000        85.500000     85.000000
# 75%               88.250000        88.250000     88.500000
# max               94.000000        94.000000     95.000000

# %%
#sample
df.sample(10) #it will show random datas from the dataframe
# Out:
#    StudentID         FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016     Ziaur Rahman                  94.0             94.0
# 8     PH1009       Omar Faruq                  72.0             72.0
# 12    PH1013     Tanvir Ahmed                  75.0             75.0
# 0     PH1001      Alif Rahman                  85.0             85.0
# 7     PH1008      Nadia Islam                  81.0             81.0
# 9     PH1010     Priya Sharma                  89.0             89.0
# 10    PH1011     Rahim Sheikh                   NaN              NaN
# 11    PH1012  Sadia Chowdhury                  85.0             85.0
# 4     PH1005      Kamal Uddin                   NaN              NaN
# 16    PH1017      Afsana Mimi                  90.0             90.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# ...

# %%
#list to dataframe
l = [ ["a",100],["b",200],["c",300]]
df = pd.DataFrame(l,columns=["key","value"])
df
# Out:
#   key  value
# 0   a    100
# 1   b    200
# 2   c    300

# %%
#dict to dataframe
dic = {'name': ['a','b','c'],
       'age': [20,30,40]}
df = pd.DataFrame(dic)
df
# Out:
#   name  age
# 0    a   20
# 1    b   30
# 2    c   40

# %%
d = [
    {'name':'a', 'age':20, 'city':'k'},
    {'name':'b', 'age':40, 'city':'d'},
    {'name':'c', 'age':25, 'city':'c'},
    {'name':'d', 'age':30, 'city':'r'},
    ]

df = pd.DataFrame(d)
df
# Out:
#   name  age city
# 0    a   20    k
# 1    b   40    d
# 2    c   25    c
# 3    d   30    r

# %%
#accessing dataframe
df = pd.read_csv('student_data.csv')

# %%
#loc [row,col]
r = df.loc[[0,10,1]] # to see specefic rows,, pass index in a list
r1 = df.loc[0:10] 
r1
c = df.loc[0:3,['Data Structure Marks','Algorithm Marks']]
c
# Out:
#    Data Structure Marks  Algorithm Marks
# 0                  85.0             85.0
# 1                  92.0             92.0
# 2                  88.0             88.0
# 3                  78.0             78.0

# %%
#changing index and column

# %%
# cyhange index
df_i = df.set_index("Location")
df_i.head()
# Out:
#            StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# Location
# Dhaka         PH1001       Alif Rahman                  85.0             85.0
# Chattogram    PH1002     Fatima Akhter                  92.0             92.0
# Dhaka         PH1003     Imran Hossain                  88.0             88.0
# Sylhet        PH1004  Jannatul Ferdous                  78.0             78.0
# Chattogram    PH1005       Kamal Uddin                   NaN              NaN
#
#             Python Marks CompletionStatus EnrollmentDate Instructor
# Location
# Dhaka               88.0        Completed     2024-01-15  Mr. Karim
# Chattogram           NaN      In Progress     2024-01-20  Ms. Salma
# Dhaka               85.0        Completed     2024-02-10  Mr. Karim
# Sylhet              82.0        Completed     2024-02-12  Ms. Salma
# Chattogram          95.0      In Progress     2024-03-05  Mr. Karim

# %%
# iloc
df_i.iloc[0:3,0:3] # it warks even if the index isn't integer
# Out:
#            StudentID       FullName  Data Structure Marks
# Location
# Dhaka         PH1001    Alif Rahman                  85.0
# Chattogram    PH1002  Fatima Akhter                  92.0
# Dhaka         PH1003  Imran Hossain                  88.0

# %%
#change column name
df.rename(columns={"FullName":"StudentName"},inplace=True)
df.head()
# Out:
#         StudentName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0       Alif Rahman                  85.0             85.0          88.0
# 1     Fatima Akhter                  92.0             92.0           NaN
# 2     Imran Hossain                  88.0             88.0          85.0
# 3  Jannatul Ferdous                  78.0             78.0          82.0
# 4       Kamal Uddin                   NaN              NaN          95.0
#
#   CompletionStatus EnrollmentDate Instructor    Location
# 0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2        Completed     2024-02-10  Mr. Karim       Dhaka
# 3        Completed     2024-02-12  Ms. Salma      Sylhet
# 4      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
#delete col or row

#df.drop('StudentID',axis=1)
#df.drop(0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 3
#       1 #delete col or row
#       2 #df.drop('StudentID',axis=1)
# ----> 3 df.drop(0,inplace=True)
#       4 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df
# Out:
#          StudentName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 1      Fatima Akhter                  92.0             92.0           NaN
# 2      Imran Hossain                  88.0             88.0          85.0
# 3   Jannatul Ferdous                  78.0             78.0          82.0
# 4        Kamal Uddin                   NaN              NaN          95.0
# 5        Laila Begum                  75.0             75.0          78.0
# 6     Mahmudul Hasan                  80.0             80.0           NaN
# 7        Nadia Islam                  81.0             81.0          85.0
# 8         Omar Faruq                  72.0             72.0          76.0
# 9       Priya Sharma                  89.0             89.0          88.0
# 10      Rahim Sheikh                   NaN              NaN          91.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 12      Tanvir Ahmed                  75.0             75.0          79.0
# ...

# %%
# assign to specific place
df.loc[1,'Python Marks'] = 90
df.loc[1,'CompletionStatus'] = "Complete"
df.loc[1:4,'Python Marks'] += 1 
df
# Out:
#          StudentName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 1      Fatima Akhter                  92.0             92.0          91.0
# 2      Imran Hossain                  88.0             88.0          86.0
# 3   Jannatul Ferdous                  78.0             78.0          83.0
# 4        Kamal Uddin                   NaN              NaN          96.0
# 5        Laila Begum                  75.0             75.0          78.0
# 6     Mahmudul Hasan                  80.0             80.0           NaN
# 7        Nadia Islam                  81.0             81.0          85.0
# 8         Omar Faruq                  72.0             72.0          76.0
# 9       Priya Sharma                  89.0             89.0          88.0
# 10      Rahim Sheikh                   NaN              NaN          91.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 12      Tanvir Ahmed                  75.0             75.0          79.0
# ...

# %%
for i,series in df.iterrows():
    print(f"{i} : {series}")
# Out:
# 1 : StudentName             Fatima Akhter
# Data Structure Marks             92.0
# Algorithm Marks                  92.0
# Python Marks                     91.0
# CompletionStatus             Complete
# EnrollmentDate             2024-01-20
# Instructor                  Ms. Salma
# Location                   Chattogram
# Name: 1, dtype: object
# 2 : StudentName             Imran Hossain
# Data Structure Marks             88.0
# Algorithm Marks                  88.0
# Python Marks                     86.0
# CompletionStatus            Completed
# EnrollmentDate             2024-02-10
# Instructor                  Mr. Karim
# Location                        Dhaka
# Name: 2, dtype: object
# 3 : StudentName             Jannatul Ferdous
# Data Structure Marks                78.0
# Algorithm Marks                     78.0
# Python Marks                        83.0
# CompletionStatus               Completed
# EnrollmentDate                2024-02-12
# ...

# %%
for i in df.itertuples():
    print(f"{i}")
# Out:
# Pandas(Index=1, StudentName='Fatima Akhter', _2=92.0, _3=92.0, _4=91.0, CompletionStatus='Complete', EnrollmentDate='2024-01-20', Instructor='Ms. Salma', Location='Chattogram')
# Pandas(Index=2, StudentName='Imran Hossain', _2=88.0, _3=88.0, _4=86.0, CompletionStatus='Completed', EnrollmentDate='2024-02-10', Instructor='Mr. Karim', Location='Dhaka')
# Pandas(Index=3, StudentName='Jannatul Ferdous', _2=78.0, _3=78.0, _4=83.0, CompletionStatus='Completed', EnrollmentDate='2024-02-12', Instructor='Ms. Salma', Location='Sylhet')
# Pandas(Index=4, StudentName='Kamal Uddin', _2=nan, _3=nan, _4=96.0, CompletionStatus='In Progress', EnrollmentDate='2024-03-05', Instructor='Mr. Karim', Location='Chattogram')
# Pandas(Index=5, StudentName='Laila Begum', _2=75.0, _3=75.0, _4=78.0, CompletionStatus='Completed', EnrollmentDate='2024-03-08', Instructor='Ms. Salma', Location='Rajshahi')
# ...

# %%
#sorting
copy = df.sort_values(["Algorithm Marks","Python Marks"]) #that will sort in order.. first algo then python
copy
# Out:
#          StudentName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 8         Omar Faruq                  72.0             72.0          76.0
# 5        Laila Begum                  75.0             75.0          78.0
# 12      Tanvir Ahmed                  75.0             75.0          79.0
# 3   Jannatul Ferdous                  78.0             78.0          83.0
# 6     Mahmudul Hasan                  80.0             80.0           NaN
# 7        Nadia Islam                  81.0             81.0          85.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 14      Wahiduzzaman                  86.0             86.0          84.0
# 19        Nasir Khan                  86.0             86.0          89.0
# 17       Babul Ahmed                  88.0             88.0          85.0
# 2      Imran Hossain                  88.0             88.0          86.0
# 9       Priya Sharma                  89.0             89.0          88.0
# ...

# %%
notStarted = df.loc[df["CompletionStatus"]=="Not Started"]
notStarted
# Out:
#      StudentName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 13    Urmi Akter                   NaN              NaN           NaN
# 18  Faria Rahman                   NaN              NaN           NaN
#
#    CompletionStatus EnrollmentDate Instructor    Location
# 13      Not Started     2024-07-09  Ms. Salma    Rajshahi
# 18      Not Started     2025-09-15  Mr. David  Chattogram

# %%
comp = df.loc[(df["CompletionStatus"]=="Completed") & (df["Algorithm Marks"]>df["Python Marks"])]
comp
# Out:
#       StudentName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 2   Imran Hossain                  88.0             88.0          86.0
# 9    Priya Sharma                  89.0             89.0          88.0
# 14   Wahiduzzaman                  86.0             86.0          84.0
# 17    Babul Ahmed                  88.0             88.0          85.0
#
#    CompletionStatus EnrollmentDate Instructor Location
# 2         Completed     2024-02-10  Mr. Karim    Dhaka
# 9         Completed     2024-05-20  Ms. Salma   Sylhet
# 14        Completed     2024-08-18  Mr. Karim    Dhaka
# 17        Completed     2025-09-05  Ms. Salma   Sylhet
